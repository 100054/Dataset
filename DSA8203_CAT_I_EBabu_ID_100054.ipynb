# %% [markdown]
# <a href="https://colab.research.google.com/github/100054/Dataset/blob/main/DSA8203_CAT_I_EBabu_ID_100054.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
#import libraries to be used
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#import dataset

df=pd.read_csv('https://github.com/100054/Dataset/raw/main/Metadata_Indicator_API_GHA_DS2_en_csv_v2_6003936.csv')
df.head()
# Out:
#          INDICATOR_CODE                                     INDICATOR_NAME  \
# 0     SL.UEM.NEET.MA.ZS  Share of youth not in education, employment or...
# 1     SL.UEM.INTM.FE.ZS  Unemployment with intermediate education, fema...
# 2        SL.UEM.ADVN.ZS  Unemployment with advanced education (% of tot...
# 3     SL.UEM.1524.NE.ZS  Unemployment, youth total (% of total labor fo...
# 4  SL.UEM.1524.FE.NE.ZS  Unemployment, youth female (% of female labor ...
#
#                                          SOURCE_NOTE  \
# 0  Share of youth not in education, employment or...
# 1  The percentage of the labor force with an inte...
# 2  The percentage of the labor force with an adva...
# 3  Youth unemployment refers to the share of the ...
# 4  Youth unemployment refers to the share of the ...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  International Labour Organization. “Labour For...         NaN
# ...

# %% [markdown]
# Question 4. What issues or challenges are you experiencing with your dataset if any?
#
# -Dataset has duplicate information.  This may require additional effort to identify and aggregate the necessary information from different duplicates.

# %% [markdown]
# Question 5.Consider who would be interested in your dataset. Identify at least three organizations or individuals that would be interested in your insights. Why?
#
# a. Government Labor Departments- Government labor departments at national, regional, or local levels would be interested in these insights to formulate and evaluate labor policies. Data on unemployment rates, labor force participation, and education levels can help them make informed decisions to address unemployment challenges and promote workforce development.
#
# b. International Labor Organization (ILO)- The ILO is a specialized agency of the United Nations that deals with labor issues, including international labor standards, social protection, and employment. Insights into global and regional labor market trends, unemployment rates, and education levels are crucial for the ILO to develop policies and guidelines that promote decent work and social justice worldwide.
#
# c. Academic Researchers and Think Tanks- Researchers and think tanks focused on labor economics, sociology, and public policy may find value in the dataset to conduct in-depth analyses. The data can be used to study trends over time, explore correlations between different labor indicators, and contribute to the academic understanding of labor markets and their complexities.

# %% [markdown]
# Question 8. Create a function that accepts the raw data after it has been loaded and returns the cleaned-up data.

# %%
def clean_and_display_data(df):
    cleaned_data = df.dropna()
    cleaned_data

    # Return the cleaned data
    return cleaned_data

# %%
df
# Out:
#             INDICATOR_CODE                                     INDICATOR_NAME  \
# 0        SL.UEM.NEET.MA.ZS  Share of youth not in education, employment or...
# 1        SL.UEM.INTM.FE.ZS  Unemployment with intermediate education, fema...
# 2           SL.UEM.ADVN.ZS  Unemployment with advanced education (% of tot...
# 3        SL.UEM.1524.NE.ZS  Unemployment, youth total (% of total labor fo...
# 4     SL.UEM.1524.FE.NE.ZS  Unemployment, youth female (% of female labor ...
# ...                    ...                                                ...
# 1472        AG.LND.PRCP.MM       Average precipitation in depth (mm per year)
# 1473        AG.LND.EL5M.ZS  Land area where elevation is below 5 meters (%...
# 1474     AG.LND.EL5M.RU.K2  Rural land area where elevation is below 5 met...
# 1475     AG.LND.ARBL.HA.PC                  Arable land (hectares per person)
# 1476        AG.CON.FERT.ZS  Fertilizer consumption (kilograms per hectare ...
#
# ...

# %% [markdown]
# PART II
#
# Explain how two of the issues raised in this video may impact the dataset from your assigned country.

# %% [markdown]
# In Ghana, challenges in data infrastructure and quality can impede socio-economic development. Insufficient data infrastructure hampers efficient information flow, hindering informed decision-making for governance and development programs. Poor data quality may lead to inaccurate policy formulation and resource allocation. In healthcare, it can affect disease monitoring and response planning. In education, inadequate data may compromise educational planning and resource distribution. Additionally, businesses may face obstacles in market research and strategic planning. Addressing these issues is crucial for Ghana to overcome developmental challenges, as robust data systems are pivotal for evidence-based policymaking and sustainable progress in various sectors.
